# %% [markdown]
# # **Plots for hypothesis 2**

# %% [markdown]
# ### Imports

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from src.visualization import plot_chord

from sklearn.linear_model import LinearRegression
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# #### 2.2.a. Top pesticides in MILK samples among MANDATORY PROGRAMMES by country of SAMPLING

# %%
df22a = pd.read_csv('../results/results/2_2_a_top_detected_pests_milk_o.csv')
plot_chord(df=df22a, product='milk', country_type='reporting')

# %% [markdown]
# #### 2.2.b. Top pesticides in MILK samples among NON-MANDATORY PROGRAMMES by country of SAMPLING

# %%
df22b = pd.read_csv('../results/results/2_2_b_top_detected_pests_milk_no.csv')
plot_chord(df=df22b, product='milk', country_type='reporting')

# %% [markdown]
# #### 2.2.c. Top pesticides in MILK samples among ALL PROGRAMMES by country of SAMPLING

# %%
df22c = pd.read_csv('../results/results/2_2_c_top_detected_pests_milk_all_programmes.csv')
plot_chord(df=df22c, product='milk', country_type='reporting')

# %% [markdown]
# #### 2.2.d. Top pesticides in BUTTER samples among MANDATORY PROGRAMMES by country of SAMPLING

# %%
df22d = pd.read_csv('../results/results/2_2_d_top_detected_pests_butter_o.csv')
plot_chord(df=df22d, product='butter', country_type='reporting')

# %% [markdown]
# #### 2.2.e. Top pesticides in BUTTER samples among NON-MANDATORY PROGRAMMES by country of SAMPLING

# %%
df22E = pd.read_csv('../results/results/2_2_e_top_detected_pests_butter_no.csv')
plot_chord(df=df22a, product='butter', country_type='reporting')

# %% [markdown]
# #### 2.2.f. Top pesticides in BUTTER samples among ALL PROGRAMMES by country of SAMPLING

# %%
df22f = pd.read_csv('../results/results/2_2_f_top_detected_pests_butter_all_programmes.csv')
plot_chord(df=df22f, product='butter', country_type='reporting')

# %% [markdown]
# #### 2.2.g. Top pesticides in MILK samples among MANDATORY PROGRAMMES by country of ORIGIN

# %%
df22g = pd.read_csv('../results/results/2_2_g_top_detected_pests_origin_milk_o.csv')
plot_chord(df=df22g, product='milk', country_type='origin')

# %% [markdown]
# #### 2.2.h. Top pesticides in MILK samples among NON-MANDATORY PROGRAMMES by country of ORIGIN

# %%
df22g = pd.read_csv('../results/results/2_2_h_top_detected_pests_origin_milk_no.csv')
plot_chord(df=df22g, product='milk', country_type='origin')

# %% [markdown]
# #### 2.2.i. Top pesticides in MILK samples among ALL PROGRAMMES by country of ORIGIN

# %%
df22i = pd.read_csv('../results/results/2_2_i_top_detected_pests_origin_milk_all_programmes.csv')
plot_chord(df=df22i, product='milk', country_type='origin')

# %% [markdown]
# #### 2.2.j. Top pesticides in BUTTER samples among MANDATORY PROGRAMMES by country of ORIGIN

# %%
df22g = pd.read_csv('../results/results/2_2_j_top_detected_pests_origin_butter_o.csv')
plot_chord(df=df22g, product='butter', country_type='origin')

# %% [markdown]
# #### 2.2.k. Top pesticides in BUTTER samples among NON-MANDATORY PROGRAMMES by country of ORIGIN

# %%
df22g = pd.read_csv('../results/results/2_2_k_top_detected_pests_origin_butter_no.csv')
plot_chord(df=df22g, product='butter', country_type='origin')

# %% [markdown]
# #### 2.2.l. Top pesticides in BUTTER samples among ALL PROGRAMMES by country of ORIGIN

# %%
df22g = pd.read_csv('../results/results/2_2_l_top_detected_pests_origin_butter_all_programmes.csv')
plot_chord(df=df22g, product='butter', country_type='origin')
