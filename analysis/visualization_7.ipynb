# %% [markdown]
# # **Chord plots for hypothesis 7**

# %% [markdown]
# ### Imports

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from src.visualization import plot_chord

from sklearn.linear_model import LinearRegression
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# Product: milk, programmes: non-mandatory

# %%
df71 = pd.read_csv('../results/results/7_country_pesticide_relation_origin_milk_no.csv')
df71 = df71.rename(columns={'sample_count': 'Number of samples with pesticide'})
plot_chord(df=df71, product='milk', country_type='origin',
           title="Chord diagram of pesticide residues detected in milk within \n the Multi-Annual National Control Plan (MANCP), 2011–2023, \n and their association with countries of origin")

# %% [markdown]
# Product: butter, programme: non-mandatory

# %%
df72 = pd.read_csv('../results/results/7_country_pesticide_relation_origin_butter_no.csv')
df72 = df72.rename(columns={'sample_count': 'Number of samples with pesticide'})
plot_chord(df=df72, product='butter', country_type='origin',
           title="Chord diagram of pesticide residues detected in butter within \n the Multi-Annual National Control Plan (MANCP), 2011–2023, \n and their association with countries of origin")
